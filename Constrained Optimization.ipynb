# %% [markdown]
# <img
# src="https://www.imt-atlantique.fr/sites/default/files/Images/Ecole/charte-graphique/IMT_Atlantique_logo_RVB_Baseline_400x272.jpg"
# WIDTH=200 HEIGHT=200>
#
# <CENTER>
# </br>
# <p><font size="5">  FISE 1A - UE Math </font></p>
# <p><font size="5">  TP 1-2 Optimisation </font></p>
# </p></br>
# <p><font size="4"> IMT Atlantique</span></p>
# <p><font size="4"> Étudiant : <span style="color:#FF0000">NDJANKO Jomuel</span> </span></p>
#
# </p>
# </CENTER>
#
# ----------------------------

# %% [markdown]
# ## <span style="color:#FF0000"> SVP, N'OUBLIEZ PAS</span>
#
# <span style="color:#FF0000"> D'AJOUTER VOTRE (VOS) NOM(S) DANS LE NOM DU FICHIER DU NOTEBOOK </span>
#
# <span style="color:#FF0000"> D'INDIQUER DANS LE NOM DE L'ENSEIGNANT DANS LE NOM DU FICHIER DU NOTEBOOK</span>
#
# <span style="color:#FF0000"> D'AJOUTER VOTRE (VOS) NOM(S) DANS LE PREMIER BLOC DU NOTEBOOK</span>
#
#
#
# ---------
#
#
# # <span style="color:#00B8DE"> Algorithmes de descente du gradient et de Newton</span>
#
#
# Nous recherchons le minimum des fonctions en testant les algorithmes du gradient et de Newton sur des exemples.
#
# **1)** Considérons la fonction $f(x,y)=(x-2)^2 (\sin(y-1))^2+x^2+y^2$.
#
# Visualiser les courbes de niveau de cette fonction sur le carré aux sommets $(\pm 3,\pm 3)$.
#
# Nous pouvons utiliser les fonctions *imshow* and *contour* de  *matplotlib*.
#
# Afficher également le minimum de $f$ sur le point $(0.0917, 0.7790)$
#
# **2)** Calculer le gradient et le hessien de cette fonction et implémenter les algorithmes du gradient et de Newton.
#
# Comparez le nombre d'itérations nécessaires à la convergence des deux algorithmes avec une initialisation au point (-1, 1) et une erreur résiduelle pour $x$ et $y$ inférieure à $10^{-4}$.
#
# Comparer l'évolution de l'erreur en fonction du nombre d'itération.
#
# Analyser vos résultats (ne pas oubliez d'utiliser vos connaissances acquises lors du cours).
#
# **3)** Testez ces algorithmes pour $f (x, y) = x^2 +2y^2$. Pour l'algorithme du gradient, la taille du pas sera choisie de façon optimale à chaque itération, de façon à ce que la taille du pas soit la même pour tous les algorithmes.
# optimale à chaque itération, de façon à minimiser la fonction dans la direction de recherche.
#
# Qu'observez-vous avec l'algorithme de Newton ? Expliquez.
#
# **4)** Pour l'algorithme de Newton, on cherche à minimiser la fonction $f(x,y)=(1 + e^{-a(x^2 +y^2)})^{-2}$
# pour $a = 0.01$ et $a = 0.1$.
#
# Qu'observez-vous ? Expliquez.
#
# ## <span style="color:#00B8DE">References</span>
#
# > - [Algorithme du Gradient](http://en.wikipedia.org/wiki/Gradient_descent)
# > - [Algorithme de Newton](http://en.wikipedia.org/wiki/Newton%27s_method_in_optimization)

# %% [markdown]
# # Réponses aux questions
# # 1) En dessous
#
#
# # 2) Au bout de 50 itérrations pour les deux algorithmes, on observe une fixation de l'image du point sortant à 1.064 (lorsque n tend vers +l'infini) et une convergence vers le point (0.43,0.44), pas mieux.
#     L'erreur reste presque constante lorsque n tend vers +l'infini.
#     Au final, l'évolution n'est pls grande parceque le pas constant p est petit.
#
#
#
# # 3) Pour la méthode de Newton, on observe qu'il y a divergence. Ceci parceque la hessienne n'est pas inversible au point (0,0).
#
#
#
#
# # 4)  erreur non détectée

# %%
# %matplotlib inline
from pylab import *

# %%
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import numpy as np
import matplotlib as mpl
from array import array


#fonction
def f(x,y): 
   return ((x-2)**2)*((np.sin(y-1))**2) + (x)**2 + (y)**2    
# gradient
def grad_f(x,y):
    return np.array([2*(x-2)*((math.sin(y-1))**2) + 2*x , 2*math.sin(y-1)*math.cos(y-1) +2*y])
def hess_f(x,y):
    return np.array([
        [2*(math.sin(y-1))**2 +2, 4*(math.sin(y-1))*(math.cos(y-1))*(x-2)],
        [0, 2 + 2*(cos(y-1))**2 - 2*(math.sin(y-1))**2]
                   ])
           
# initialisation                  
init= np.array([-1, -1])            
opt= np.array([0.0917, 0.7790])   

mpl.rcParams['figure.figsize'] = (8.0, 8.0)
                  
                  
# affichage ligne de niveau
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.imshow(Z, extent=[-3, 3, -3, 3], origin='lower', cmap='viridis', alpha=0.5)
plt.colorbar(label='Valeur de f(x, y)')
contours = plt.contour(X, Y, Z, levels=20, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

x_point = 0.0917
y_point = 0.7790
z_point = f(x_point, y_point)


plt.plot(x_point, y_point, 'ro')  
plt.text(x_point, y_point, f'({x_point}, {y_point})', color='red')
plt.title('Courbes de niveau de la fonction f(x, y)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import numpy as np
import matplotlib as mpl
from array import array


#fonction
def f(x,y): 
   return((x-2)**2)*((math.sin(y-1))**2) + (x)**2 + (y)**2    
# gradient
def gradf(x,y):
    return np.array([2*(x-2)*((math.sin(y-1))**2) + 2*x, 2*math.sin(y-1)*math.cos(y-1) +2*y])
def hessf(x,y):
    return np.array([
        [2*(math.sin(y-1))**2 +2, 4*(math.sin(y-1))*(math.cos(y-1))*(x-2)]
        [0, 2 + 2*(math.cos(y-1))**2 - 2*(math.sin(y-1))**2]
                    ])
           
# initialisation                  
init= np.array([-1, 1])            
opt= np.array([0.0917, 0.779])   

#--------------------
# gradient algorithm
#--------------------

def terme(k):
    u = init 
    for i in range(1,k):
        u = u- 0.025*(gradf(u[0],u[1]))  
    return u
err=1
tolerance= 10**(-4)
k=1            
while (err > tolerance) & (k<150) :
   err=f(terme(k)[0],terme(k)[1]) - f(opt[0],opt[1])
   k=k+1
print(f(opt[0],opt[1]))
print(" La réponse est: ", terme(k) , 'et' , k, 'puis', f(terme(k)[0],terme(k)[1]) )
# Out:
# 0.7902328836470659
#  La réponse est:  [0.43224609 0.44697562] et 150 puis 1.0647488404634915
# <>:18: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:18: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\jomue\AppData\Local\Temp\ipykernel_11304\168429979.py:18: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [2*(math.sin(y-1))**2 +2, 4*(math.sin(y-1))*(math.cos(y-1))*(x-2)]

# %%
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import numpy as np
import matplotlib as mpl
from array import array


#fonction
def f(x,y): 
   return((x-2)**2)*((math.sin(y-1))**2) + (x)**2 + (y)**2    
# gradient
def gradf(x,y):
    return np.array([2*(x-2)*((math.sin(y-1))**2) + 2*x, 2*math.sin(y-1)*math.cos(y-1) +2*y])
def hessf(x,y):
    return np.array([
        [2*(math.sin(y-1))**2 +2, 4*(math.sin(y-1))*(math.cos(y-1))*(x-2)],
        [0, 2 + 2*(math.cos(y-1))**2 - 2*(math.sin(y-1))**2]
                    ])
           
# initialisation                  
init= np.array([-1, 1])             
opt= np.array([0.0917, 0.779])   

#------------------
# Newton algorithm
#------------------
def terme(k):
    u = init  
    for i in range(1,k):
        u = u- np.dot((np.linalg.inv(hessf(u[0],u[1]))),gradf(u[0],u[1]))    
    return u
err=1
tolerance= 10**(-4)
k=1            
while (err > tolerance) & (k<150) :
   err=f(terme(k)[0],terme(k)[1])-f(opt[0],opt[1])
   k=k+1
print(f(opt[0],opt[1]))
print(" La réponse est :", terme(k), "et", k, 'et', f(terme(k)[0],terme(k)[1]) )
# Out:
# 0.7902328836470659
#  La réponse est : [0.43248704 0.44696992] et 150 et 1.0647561896466822

# %%
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import numpy as np
from array import array



def f(x,y): 
   return x**2 + 2*(y**2)
def gradf (x,y):
   return np.array([2*x, 4*y])
def hessf(x,y):
   return np.array([[2*x, 0]
                [0, 4*Y]])

init = np.array ([0.02, 0.02]) 
opt = np.array([0.0917 , 0.7790])
A= np.array([
   [1,0],
   [0,2]
   ])

#Gradient algorithm
def terme(k):
    u = init  # Initialisation du premier terme 
    for i in range(1,k):
        u = u- (((np.linalg.norm(np.dot(A,u))**2))/(np.dot(A,(np.dot(A,u)))@(np.dot(A,u))))*gradf(u[0],u[1])  # Calcul du terme suivant
    return u
err=1
tolerance= 10**(-4)
k=1          
while (err > tolerance)& (k<20)  :
   err=f(terme(k)[0],terme(k)[1])-f(opt[0],opt[1])
   k=k+1
print(" La réponse est :", terme(k) )
# Out:
#  La réponse est : [-0.00222222 -0.02444444]
# <>:15: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:15: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\jomue\AppData\Local\Temp\ipykernel_8024\1342534275.py:15: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   return np.array([[2*x, 0]

# %%
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import numpy as np
from array import array



def f(x,y): 
   return x**2 + 2*(y**2)
def gradf (x,y):
   return np.array([2*x, 4*y])
def hessf(x,y):
   return np.array([
                  [2*x, 0],
                  [0, 4*y]
                  ])

init = np.array ([0.0000000000000000000000000000000000000000000000001 , 0.000000000000000000000000000000000000001]) 




#Newton Algorithm
def terme(k):
    u = init 
    for i in range(1,k):
        u = u- np.dot((np.linalg.inv(hessf(u[0],u[1]))),gradf(u[0],u[1]))  
    return u
err=1
tolerance= 10**(-4)
k=1            
while (err > tolerance) & (k<100)  :
   err=f(terme(k)[0],terme(k)[1])-f(0,0)
   k=k+1
print(" La réponse est ", terme(k) )
# Out:
#  La réponse est  [-1. -1.]

# %%
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import numpy as np
import matplotlib as mpl
from array import array


def f(x,y): 
   return (1+ np.exp((-0.1)*(x**2 + y**2)))**(-2) 

mpl.rcParams['figure.figsize'] = (8.0, 8.0)
                  
                  
# affichage ligne de niveau
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.imshow(Z, extent=[-3, 3, -3, 3], origin='lower', cmap='viridis', alpha=0.5)
plt.colorbar(label='Valeur de f(x, y)')
contours = plt.contour(X, Y, Z, levels=20, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.title('Courbes de niveau de la fonction f(x, y)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#Newton Algorithm,a=0.01

import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import numpy as np
from array import array

init = np.array ([0.025, 0.025]) 
opt = np.array([0 , 0])


def f(x,y): 
   return (1+np.exp((-0.01)*(x**2 + y**2)))**(-2)
def gradf(x,y):
   return np.array([(4*x*(0.01)*np.exp((-0.01)*(x**2 + y**2)))*(1+np.exp((-0.01*(x**2+y**2))))**(-3)], [(4*y*(0.01)*np.exp((-0.01)*(x**2 + y**2)))*(1+np.exp((-0.01*(x**2+y**2))))**(-3)])
def hessf(x,y):
     return np.array ([ 
          [((1+np.exp(-0.01*(x**2+y**2)))**(-4))*(np.exp(-0.02(x**2+y**2)))*(0.0004*x**2-0.02) , ((1+np.exp(-0.01*(x**2+y**2)))**(-4))*(np.exp(-0.02(x**2+y**2)))*(0.004*x*y)], 
                                                                                           
         [((1+np.exp(-0.01*(x**2+y**2)))**(-4))*(np.exp(-0.02(x**2+y**2)))*(0.0004*x*y)    , ((1+np.exp(-0.01*(x**2+y**2)))**(-4))*(np.exp(-0.02(x**2+y**2)))*(0.004*y**2-0.0002)]
            ])





def terme(k):
    u = init   
    for i in range(1,k):
        u = u- np.dot((np.linalg.inv(hessf(u[0],u[1]))),gradf(u[0],u[1])) 
    return u
err=1
tolerance= 10**(-4)
k=1             
while (err > tolerance) :
   err=f(terme(k)[0],terme(k)[1])-f(opt[0],opt[1])
   k=k+1
print(hessf(0,0))
print(" La réponse est :", terme(k) )
# Out:
# <>:20: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:20: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:22: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:22: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:20: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:20: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:22: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:22: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# C:\Users\jomue\AppData\Local\Temp\ipykernel_11304\3400656205.py:20: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   [((1+np.exp(-0.01*(x**2+y**2)))**(-4))*(np.exp(-0.02(x**2+y**2)))*(0.0004*x**2-0.02) , ((1+np.exp(-0.01*(x**2+y**2)))**(-4))*(np.exp(-0.02(x**2+y**2)))*(0.004*x*y)],
# ...

# %%
#Newton Algorithm,a=0.1
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
from array import array



init = np.array ([0.025,0.025]) 
opt = np.array([0 , 0])

def f(x,y): 
   return (1+np.exp((-0.1)*(x**2 + y**2)))**(-2)
def gradf(x,y):
   return np.array([(4*x*(0.1)*np.exp((-0.1)*(x**2 + y**2)))*(1+np.exp((-0.1*(x**2+y**2))))**(-3), (4*y*(0.1)*np.exp((-0.1)*(x**2 + y**2)))*(1+np.exp((-0.1*(x**2+y**2))))**(-3)])
def hessf(x,y):
    return np.array ([
        [((1+np.exp(-0.1*(x**2+y**2)))**(-4))*(np.exp(-0.2(x**2+y**2)))*(0.04*x**2-0.02) , ((1+np.exp(-0.1*(x**2+y**2)))**(-4))*(np.exp(-0.2(x**2+y**2)))*(0.04*x*y)] , 
                                                                                           
         [((1+np.exp(-0.1*(x**2+y**2)))**(-4))*(np.exp(-0.2(x**2+y**2)))*(0.04*x*y)  , ((1+np.exp(-0.1*(x**2+y**2)))**(-4))*(np.exp(-0.2(x**2+y**2)))*(0.04*y**2-0.02)]
                     ])




def terme(k):
    u = init
    for i in range(1,k):
        u = u- np.dot((np.linalg.inv(hessf(u[0],u[1]))),gradf(u[0],u[1]))  
          
    return u
err=1
tolerance= 10**(-4)
k=1             
while (err > tolerance) & (k<5) :
   err=f(terme(k)[0],terme(k)[1])-f(opt[0],opt[1])
   k=k+1
print(" La réponse est ", terme(k))
# Out:
# <>:19: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:19: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:21: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:21: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:19: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:19: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:21: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:21: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# C:\Users\jomue\AppData\Local\Temp\ipykernel_11304\4038801155.py:19: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   [((1+np.exp(-0.1*(x**2+y**2)))**(-4))*(np.exp(-0.2(x**2+y**2)))*(0.04*x**2-0.02) , ((1+np.exp(-0.1*(x**2+y**2)))**(-4))*(np.exp(-0.2(x**2+y**2)))*(0.04*x*y)],
# ...
